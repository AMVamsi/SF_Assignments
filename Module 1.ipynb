# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be acquiring and handling datasets. You will be using the Cinema Data, Salary Data and Reviews Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data
# * Handling files and formats
# * Data Analysis
# * Prediction
# * Analysing results

# %% [markdown]
# ## Task 1 - Data Acquisition
# * Retrieve the CinemaData dataset from Firebase, convert it to a CSV and save it in the 'Data' folder as 'CinemaData.csv'. You may use shell scripts, other packages and any other resources you require to do this. The database can be accessed with a HTTP request, ask a TA for the link. <br>
# * Using `wget`, download the 'SalaryData.txt' and save it in the 'Data' folder. Convert it to a CSV named 'SalaryData.csv' and save it in the same folder. It is avaliable at this link: <br>
# http://bit.ly/MLSalaryData

# %%
import pandas as pd
df=pd.DataFrame()
f=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/SalaryData.txt")
sal=f.read()
import os
os.chdir(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/")
df.to_csv("Salary.csv")
f.close()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os
os.chdir(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\MLBasics-master\Data")
#os.getcwd()
# Out:
# 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data'

# %%
import json
import pandas as pd
df = pd.DataFrame()
with open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/CinemaData.json") as f:
    data = json.load(f)
    df = pd.DataFrame(data)
import os
os.chdir(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/")

    #df["ACC_x"] = df.data[0]["Capacity"])
    #df2 = df2.append(df)
    #print(data)
    
#print(data[0]["Capacity"])
df.to_csv('CinemaData.csv')
df
# Out:
#       Capacity  DaysShowedInWeek  Index    LastDate  Lifetime       Movie  \
# 0         3100                 5      0  2015-12-17         2  0001000001
# 1         3390                 7      1  2015-12-17         2  0001000001
# 2          860                 2      2  2015-12-17         2  0001000001
# 3          110                 1      3  2016-01-06         5  0001000002
# 4          720                 6      4  2016-01-06         5  0001000002
# 5         1320                 7      5  2016-01-06         5  0001000002
# 6          120                 1      6  2016-01-06         5  0001000002
# 7         2630                 5      7  2016-01-13         6  0001000003
# 8         4590                 7      8  2016-01-13         6  0001000003
# 9         1955                 7      9  2016-01-13         6  0001000003
# 10        1048                 7     10  2016-01-13         6  0001000003
# 11        1847                 7     11  2016-01-13         6  0001000003
# ...

# %% [markdown]
# ## Task 2 - Dataset Handling
# * You can find the Reviews Data in a RAR file in the 'Data' directory. Extract this dataset and use it for this module.
#
# * The dataset contains positive and negative movie reviews. The files 'Positive_Reviews.txt' and 'Negative_Reviews.txt' contain names of files having positive and negative reviews respectively. Create two directories ‘pos’ and ‘neg’, and segregate the reviews accordingly into the two directories.
#
# * Load ‘cv000_29590.csv’ and report the number of words present in the first column.
#
# * Find the number of unique words in the first column. For this task, ignore punctuations, that is, punctuations are not considered as a word or a part of it.
#
# * Lookups: OS module, String functions

# %%
import glob
import shutil
import os.path
from os import path
#import pathlib
txt_files = glob.glob(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/*.txt")
txt1=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Negative_Reviews-Copy1.txt")
neg=txt1.read()
#txt2=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Positive_Reviews.txt")
#pos=txt2.read()
#txt2.close()
li=list(neg.split(","))
os.chdir(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/")
#for i in os.listdir(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"):
#for i in txt_files:
 #   print(i)
#print(li)
#os.mkdir("/Users/msml/Vamsi/SF/MLBasics-master/Data/neg")
for i in li:
    #print(i)
    if path.isfile("/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"+i):
        print ("File exist")
    else:
        print("no")
        #file = pathlib.Path(i)
        #print(i)
    
#path.exists(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/")
    
#os.getcwd()
        


    #shutil.copy(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"+i,"/Users/msml/Vamsi/SF/MLBasics-master/Data/neg/")
    
#r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"+i
#txt1.close()
#print(j)  
#print(neg)
#print(pos)

#print(i)
#print(txt_files)
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...

# %%
neg=list(neg.split(','))
for i in neg:
    print(i)
# Out:
#      cv367_24065.txt
#    cv385_29621.txt
#    cv241_24602.txt
#    cv433_10443.txt
#    cv858_20266.txt
#    cv798_24779.txt
#    cv895_22200.txt
#    cv502_10970.txt
#    cv096_12262.txt
#    cv984_14006.txt
#    cv339_22452.txt
#    cv539_21865.txt
#    cv707_11421.txt
#    cv596_4367.txt
#    cv503_11196.txt
#    cv909_9973.txt
#    cv615_15734.txt
#    cv887_5306.txt
#    cv229_15200.txt
#    cv665_29386.txt
#    cv907_3193.txt
#    cv899_17812.txt
#    cv860_15520.txt
#    cv283_11963.txt
#    cv165_2389.txt
#    cv748_14044.txt
#    cv362_16985.txt
#    cv772_12971.txt
#    cv069_11613.txt
#    cv040_8829.txt
#    cv216_20165.txt
#    cv305_9937.txt
#    cv951_11816.txt
#    cv685_5710.txt
#    cv746_10471.txt
#    cv000_29416.txt
#    cv618_9469.txt
#    cv410_25624.txt
#    cv513_7236.txt
#    cv505_12926.txt
#    cv284_20530.txt
#    cv369_14245.txt
#    cv056_14663.txt
#    cv735_20218.txt
#    cv318_11146.txt
#    cv929_1841.txt
#    cv303_27366.txt
#    cv955_26154.txt
# ...

# %%
type(li)
# Out:
# list

# %%
import os.path
from os import path

def main():
    os.chdir(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/")
    print("Is it File?" + str(path.isfile('cv772_12971.txt')))
    print("Is it File?" + str(path.isfile('cv889_22670.txt')))
if __name__== "__main__":
    main()
# Out:
# Is it File?True
# Is it File?True

# %%
shells 
os.listdir

# %%
import glob
import shutil
import os.path
from os import path

txt_files = glob.glob(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/*.txt")
txt1=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Negative_Reviews-Copy1.txt")
neg=txt1.read()
#txt2=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Positive_Reviews.txt")
#pos=txt2.read()
#txt2.close()
li=list(neg.split(","))
for i in li:
# Out:
# ['cv367_24065.txt'
#  'cv385_29621.txt'
#  'cv241_24602.txt'
#  'cv433_10443.txt'
#  'cv858_20266.txt'
#  'cv798_24779.txt'
#  'cv895_22200.txt'
#  'cv502_10970.txt'
#  'cv096_12262.txt'
#  'cv984_14006.txt'
#  'cv339_22452.txt'
#  'cv539_21865.txt'
#  'cv707_11421.txt'
#  'cv596_4367.txt'
#  'cv503_11196.txt'
#  'cv909_9973.txt'
#  'cv615_15734.txt'
#  'cv887_5306.txt'
#  'cv229_15200.txt'
#  'cv665_29386.txt'
#  'cv907_3193.txt'
#  'cv899_17812.txt'
#  'cv860_15520.txt'
#  'cv283_11963.txt'
#  'cv165_2389.txt'
#  'cv748_14044.txt'
#  'cv362_16985.txt'
#  'cv772_12971.txt'
#  'cv069_11613.txt'
#  'cv040_8829.txt'
#  'cv216_20165.txt'
#  'cv305_9937.txt'
#  'cv951_11816.txt'
#  'cv685_5710.txt'
#  'cv746_10471.txt'
#  'cv000_29416.txt'
#  'cv618_9469.txt'
#  'cv410_25624.txt'
#  'cv513_7236.txt'
#  'cv505_12926.txt'
#  'cv284_20530.txt'
#  'cv369_14245.txt'
#  'cv056_14663.txt'
#  'cv735_20218.txt'
#  'cv318_11146.txt'
#  'cv929_1841.txt'
#  'cv303_27366.txt'
#  'cv955_26154.txt'
# ...

# %%
import pathlib
file = pathlib.Path('cv000_29590.csv')
if file.exists ():
    print ("File exist")
else:
    print ("File not exist")
# Out:
# File not exist

# %%
print(li[1])
# Out:
#  'cv385_29621.txt'

# %%
import glob
import shutil
import os.path
from os import path

txt_files = glob.glob(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/*.txt")
txt3=open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/cv000_29590.txt")
file=txt3.read()
print(file)
# Out:
# films adapted from comic books have had plenty of success , whether they're about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there's never really been a comic book like from hell before .
# for starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid '80s with a 12-part series called the watchmen .
# to say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd .
# the book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes .
# in other words , don't dismiss this film because of its source .
# if you can get past the whole comic book thing , you might find another stumbling block in from hell's directors , albert and allen hughes .
# ...

# %%
import pandas as pd 
count=0
uni=0
df=pd.DataFrame()
df = pd.read_csv(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/cv000_29590.txt",
                   sep=";|:|,",
                   header=None,
                   engine='python')
dict=[]
for i in df[0]:
    word=i.split(" ")
    
    dict=dict+word
    count+=len(word)
    uni_word=set(dict)
    #print(i)
    #print(word)
#print(dict)
#print(uni_word)
print("number of unique words:",len(uni_word))
print("number of words:",count-24)
# Out:
# number of unique words: 176
# number of words: 247

# %%
for j in os.listdir("/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"):
    if i in j:
        print("yes")
    else:
        print("no")
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...

# %%
pwd
# Out:
# '/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews'

# %%
for j in os.listdir("/Users/msml/Vamsi/SF/MLBasics-master/Data/Assignment_1_a-1/Reviews/"):
    if i in j:
        print(i)
# Out:
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# t
# ...
