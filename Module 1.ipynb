# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be acquiring and handling datasets. You will be using the Cinema Data, Salary Data and Reviews Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data
# * Handling files and formats
# * Data Analysis
# * Prediction
# * Analysing results

# %% [markdown]
# ## Task 1 - Data Acquisition
# * Retrieve the CinemaData dataset from Firebase, convert it to a CSV and save it in the 'Data' folder as 'CinemaData.csv'. You may use shell scripts, other packages and any other resources you require to do this. The database can be accessed with a HTTP request, ask a TA for the link. <br>
# * Using `wget`, download the 'SalaryData.txt' and save it in the 'Data' folder. Convert it to a CSV named 'SalaryData.csv' and save it in the same folder. It is avaliable at this link: <br>
# http://bit.ly/MLSalaryData

# %%
import pandas as pd
df=pd.DataFrame()
f=open(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\salary.txt")
sal=f.read()
import os
os.chdir(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\MLBasics-master\Data")
df.to_csv("Salary.csv")
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os
os.chdir(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\MLBasics-master\Data")
#os.getcwd()
# Out:
# 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data'

# %%
import json
import pandas as pd
df = pd.DataFrame()
with open(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\CinemaData.json") as f:
    data = json.load(f)
    df = pd.DataFrame(data)
import os
os.chdir(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\MLBasics-master\Data")

    #df["ACC_x"] = df.data[0]["Capacity"])
    #df2 = df2.append(df)
    #print(data)
    
#print(data[0]["Capacity"])
df.to_csv('CinemaData.csv')
df
# Out:
#       Capacity  DaysShowedInWeek  Index    LastDate  Lifetime       Movie  \
# 0         3100                 5      0  2015-12-17         2  0001000001
# 1         3390                 7      1  2015-12-17         2  0001000001
# 2          860                 2      2  2015-12-17         2  0001000001
# 3          110                 1      3  2016-01-06         5  0001000002
# 4          720                 6      4  2016-01-06         5  0001000002
# ...        ...               ...    ...         ...       ...         ...
# 3505       120                 1   3505  2017-11-15         0  HO00002188
# 3506      2410                 2   3506  2017-11-18         0  HO00002193
# 3507       330                 2   3507  2017-11-18         0  HO00002196
# 3508       360                 2   3508  2017-11-18         0  HO00002197
# 3509       220                 2   3509  2017-11-18         0  HO00002198
#
#       OccAtWeek    OccPer  OtherReleasesInWeek ReleaseDate  ShowsInWeek  \
# 0          2494  0.804516                    8  2015-12-04           10
# 1          1932  0.569912                    4  2015-12-04           14
# 2           222  0.258140                    4  2015-12-04            4
# 3            59  0.536364                    8  2015-12-04            1
# 4           630  0.875000                    7  2015-12-04            6
# ...         ...       ...                  ...         ...          ...
# 3505        112  0.933333                    7  2017-11-15            1
# 3506       2318  0.961826                    7  2017-11-17            9
# 3507        255  0.772727                    7  2017-11-17            3
# 3508        304  0.844444                    7  2017-11-17            3
# 3509        162  0.736364                    7  2017-11-17            2
#
#       WeeksSinceRelease
# 0                     0
# 1                     1
# 2                     2
# 3                     0
# 4                     3
# ...                 ...
# 3505                  0
# 3506                  0
# 3507                  0
# 3508                  0
# 3509                  0
#
# [3510 rows x 12 columns]

# %% [markdown]
# ## Task 2 - Dataset Handling
# * You can find the Reviews Data in a RAR file in the 'Data' directory. Extract this dataset and use it for this module.
#
# * The dataset contains positive and negative movie reviews. The files 'Positive_Reviews.txt' and 'Negative_Reviews.txt' contain names of files having positive and negative reviews respectively. Create two directories ‘pos’ and ‘neg’, and segregate the reviews accordingly into the two directories.
#
# * Load ‘cv000_29590.csv’ and report the number of words present in the first column.
#
# * Find the number of unique words in the first column. For this task, ignore punctuations, that is, punctuations are not considered as a word or a part of it.
#
# * Lookups: OS module, String functions

# %%
import glob
txt_files = glob.glob(r"C:\Users\hp\AppData\Local\Programs\Python\Python37-32\Scripts\ML_basics\MLBasics-master\Data\Assignment_1_a\Reviews/*.txt")
print(txt_files)
# Out:
# ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv000_29416.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv000_29590.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv001_18431.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv001_19502.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv002_15918.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv002_17424.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv003_11664.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv003_12683.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv004_11636.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv004_12641.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv005_29357.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv005_29443.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv006_15448.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv006_17022.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv007_4968.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv007_4992.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv008_29326.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv008_29435.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv009_29417.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv009_29592.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv010_29063.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv010_29198.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv011_12166.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv011_13044.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv012_29411.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\cv012_29576.txt', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python37-32\\Scripts\\ML_basics\\MLBasics-master\\Data\\Assignment_1_a\\Revie ...
